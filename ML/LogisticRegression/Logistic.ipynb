# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## Logistic Regression Overview

# %% [markdown]
# 기존 접근의 문제점들
# - (1 = 강아지, 0 = 고양이)과 같이 0과 1로 분류한다고 했을 때, 1 이상 또는 0 이하의 수들이 나오는 걸 어떻게 해석할 것인지
# - 1 또는 9으로 정확히 표현이 불가능한 경우
# - 즉, 확률로 발생할 사건의 가능성을 표현해야 한다!

# %% [markdown]
# ## Sigmoid Function

# %% [markdown]
# Odds Ratio
# - 사건이 일어날 확률과 일어나지 않을 확률의 비율
#   - 어떤 사건이 일어날 가능성
#   - 두 사건 A와 B 사이의 연관성의 강도를 수량화
# - ![image.png](attachment:image.png)
#
# Logit Function
# - X의 값이 주어졌을 때, y의 확률을 이용한 log odds
#   - odds ratio에 log를 붙인 것!

# %% [markdown]
# Sigmoid Function
# - Logit 함수의 역함수로, z에 관한 확률을 산출하도록 함
# - 미분 가능한 연속구간으로 변환된다
# - ![image.png](attachment:image.png)

# %% [markdown]
# ## Cost Function

# %% [markdown]
# - 가설함수는 sigmoid function으로 한다!
#   - ![image.png](attachment:image.png)
#   - ![image.png](attachment:image-2.png)

# %% [markdown]
# 즉, cost function
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 가중치 업데이트
# ![image.png](attachment:image.png)

# %% [markdown]
# 세타 j에 대하여,
# ![image.png](attachment:image.png)
