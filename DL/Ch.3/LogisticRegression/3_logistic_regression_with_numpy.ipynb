(8,69000,1),(7.3,72000,1),(3.3,50000,0),(3.9,58000,0),(2.6,49000,0),(1.6,78000,0),(0.7,56000,0),(2.1,36000,1),(7.5,90000,0),(4.8,59000,1),(8.9,95000,0),(6.2,72000,0),(6.3,63000,0),(9.1,100000,0),(7.3,61000,1),(5.6,74000,0),(0.5,66000,0),(1.1,59000,0),(5.1,61000,0),(6.2,70000,0),(6.6,56000,1),(6.3,76000,0),(6.5,78000,0),(5.1,59000,0),(9.5,74000,1),(4.5,64000,0),(2,54000,0),(1,52000,0),(4,69000,0),(6.5,76000,0),(3,60000,0),(4.5,63000,0),(7.8,70000,0),(3.9,60000,1),(0.8,51000,0),(4.2,78000,0),(1.1,54000,0),(6.2,60000,0),(2.9,59000,0),(2.1,52000,0),(8.2,87000,0),(4.8,73000,0),(2.2,42000,1),(9.1,98000,0),(6.5,84000,0),(6.9,73000,0),(5.1,72000,0),(9.1,69000,1),(9.8,79000,1),]
data = np.array(list(map(list, data))) # change tuples to lists
paid_data = data[np.where(data[:,2]==1)]
unpaid_data = data[np.where(data[:,2]==0)]

# %%
data
# Out:
# array([[7.00e-01, 4.80e+04, 1.00e+00],
#        [1.90e+00, 4.80e+04, 0.00e+00],
#        [2.50e+00, 6.00e+04, 1.00e+00],
#        [4.20e+00, 6.30e+04, 0.00e+00],
#        [6.00e+00, 7.60e+04, 0.00e+00],
#        [6.50e+00, 6.90e+04, 0.00e+00],
#        [7.50e+00, 7.60e+04, 0.00e+00],
#        [8.10e+00, 8.80e+04, 0.00e+00],
#        [8.70e+00, 8.30e+04, 1.00e+00],
#        [1.00e+01, 8.30e+04, 1.00e+00],
#        [8.00e-01, 4.30e+04, 0.00e+00],
#        [1.80e+00, 6.00e+04, 0.00e+00],
#        [1.00e+01, 7.90e+04, 1.00e+00],
#        [6.10e+00, 7.60e+04, 0.00e+00],
#        [1.40e+00, 5.00e+04, 0.00e+00],
#        [9.10e+00, 9.20e+04, 0.00e+00],
#        [5.80e+00, 7.50e+04, 0.00e+00],
#        [5.20e+00, 6.90e+04, 0.00e+00],
#        [1.00e+00, 5.60e+04, 0.00e+00],
#        [6.00e+00, 6.70e+04, 0.00e+00],
#        [4.90e+00, 7.40e+04, 0.00e+00],
#        [6.40e+00, 6.30e+04, 1.00e+00],
#        [6.20e+00, 8.20e+04, 0.00e+00],
#        [3.30e+00, 5.80e+04, 0.00e+00],
#        [9.30e+00, 9.00e+04, 1.00e+00],
#        [5.50e+00, 5.70e+04, 1.00e+00],
#        [9.10e+00, 1.02e+05, 0.00e+00],
#        [2.40e+00, 5.40e+04, 0.00e+00],
#        [8.20e+00, 6.50e+04, 1.00e+00],
#        [5.30e+00, 8.20e+04, 0.00e+00],
#        [9.80e+00, 1.07e+05, 0.00e+00],
#        [1.80e+00, 6.40e+04, 0.00e+00],
#        [6.00e-01, 4.60e+04, 1.00e+00],
#        [8.00e-01, 4.80e+04, 0.00e+00],
fig, ax = plt.subplots()

x, y = paid_data[:,0],paid_data[:,1]
scale = 50.0
ax.scatter(x, y, c="red", s=scale, label="paid",
               alpha=0.3, edgecolors='none')

x, y = unpaid_data[:,0],unpaid_data[:,1]
scale = 50.0
ax.scatter(x, y, c="blue", s=scale, label="ubpaid",
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()

# %% [markdown]
# ### normalize

# %%
from sklearn.preprocessing import normalize

data[:, :2] = normalize(data[:, :2], axis=0) # data normalize
data[:5]
# Out:
# array([[0.00861027, 0.04956583, 1.        ],
#        [0.02337075, 0.04956583, 0.        ],
#        [0.03075098, 0.06195729, 1.        ],
#        [0.05166165, 0.06505516, 0.        ],
#        [0.07380236, 0.07847924, 0.        ]])

# %%
x_data = data[:, :2]
x_data = np.insert(x_data, 0 , 1, axis=1) # 상수항 부분 추가
x_data
# Out:
# array([[1.        , 0.00861027, 0.04956583],
#        [1.        , 0.02337075, 0.04956583],
#        [1.        , 0.03075098, 0.06195729],
#        [1.        , 0.05166165, 0.06505516],
#        [1.        , 0.07380236, 0.07847924],
#        [1.        , 0.07995255, 0.07125089],
#        [1.        , 0.09225295, 0.07847924],
#        [1.        , 0.09963318, 0.0908707 ],
#        [1.        , 0.10701342, 0.08570759],
#        [1.        , 0.12300393, 0.08570759],
#        [1.        , 0.00984031, 0.04440273],
#        [1.        , 0.02214071, 0.06195729],
#        [1.        , 0.12300393, 0.0815771 ],
#        [1.        , 0.0750324 , 0.07847924],
#        [1.        , 0.01722055, 0.05163108],
#        [1.        , 0.11193357, 0.09500118],
#        [1.        , 0.07134228, 0.07744662],
#        [1.        , 0.06396204, 0.07125089],
#        [1.        , 0.01230039, 0.05782681],
#        [1.        , 0.07380236, 0.06918564],
#        [1.        , 0.06027192, 0.07641399],
#        [1.        , 0.07872251, 0.06505516],
#        [1.        , 0.07626244, 0.08467497],
#        [1.        , 0.0405913 , 0.05989205],
#        [1.        , 0.11439365, 0.09293594],
#        [1.        , 0.06765216, 0.05885943],
#        [1.        , 0.11193357, 0.1053274 ],
#        [1.        , 0.02952094, 0.05576156],
#        [1.        , 0.10086322, 0.0671204 ],
#        [1.        , 0.06519208, 0.08467497],
#        [1.        , 0.12054385, 0.11049051],
#        [1.        , 0.02214071, 0.06608778],
#        [1.        , 0.00738024, 0.04750059],
#        [1.        , 0.00984031, 0.04956583],
#        [1.        , 0.10578338, 0.08674021],
#        [1.        , 0.00738024, 0.04646797],
#        [1.        , 0.0061502 , 0.03097865],
#        [1.        , 0.08979287, 0.09190332],
#        [1.        , 0.03075098, 0.04956583],
#        [1.        , 0.0688822 , 0.07847924],
#        [1.        , 0.09102291, 0.07951186],
#        [1.        , 0.03321106, 0.05782681],
#        [1.        , 0.00861027, 0.04956583],
#        [1.        , 0.01476047, 0.0433701 ],
#        [1.        , 0.00246008, 0.03304389],
#        [1.        , 0.05781185, 0.05782681],
#        [1.        , 0.0344411 , 0.04543535],
#        [1.        , 0.09348299, 0.08054448],
#        [1.        , 0.01353043, 0.06505516],
#        [1.        , 0.09840314, 0.0815771 ],
#        [1.        , 0.03321106, 0.05782681],
#        [1.        , 0.07380236, 0.05369632],
#        [1.        , 0.05658181, 0.05782681],
#        [1.        , 0.03075098, 0.0526637 ],
#        [1.        , 0.07011224, 0.07331613],
#        [1.        , 0.03567114, 0.0671204 ],
#        [1.        , 0.01353043, 0.03407651],
#        [1.        , 0.03690118, 0.06402254],
#        [1.        , 0.04920157, 0.07331613],
#        [1.        , 0.02952094, 0.06298991],
#        [1.        , 0.09225295, 0.07744662],
#        [1.        , 0.11931381, 0.08364234],
#        [1.        , 0.03936126, 0.06402254],
#        [1.        , 0.0971731 , 0.0908707 ],
#        [1.        , 0.05781185, 0.04543535],
#        [1.        , 0.03075098, 0.05679418],
#        [1.        , 0.01968063, 0.04233748],
#        [1.        , 0.08241263, 0.06608778],
#        [1.        , 0.08487271, 0.06815302],
#        [1.        , 0.0971731 , 0.08054448],
#        [1.        , 0.09963318, 0.1053274 ],
#        [1.        , 0.06519208, 0.04956583],
#        [1.        , 0.10455334, 0.06815302],
#        [1.        , 0.00246008, 0.05782681],
#        [1.        , 0.07380236, 0.07125089],
#        [1.        , 0.09225295, 0.07951186],
#        [1.        , 0.09840314, 0.08880545],
#        [1.        , 0.05412173, 0.07021826],
#        [1.        , 0.06027192, 0.07744662],
#        [1.        , 0.01845059, 0.06195729],
#        [1.        , 0.02706086, 0.05163108],
#        [1.        , 0.04182134, 0.05059846],
#        [1.        , 0.05166165, 0.07228351],
#        [1.        , 0.09471302, 0.10119691],
#        [1.        , 0.10086322, 0.08777283],
#        [1.        , 0.06642212, 0.0908707 ],
#        [1.        , 0.00123004, 0.04750059],
#        [1.        , 0.01845059, 0.038207  ],
#        [1.        , 0.07749247, 0.08880545],
#        [1.        , 0.04551145, 0.05885943],
#        [1.        , 0.1033233 , 0.08777283],
#        [1.        , 0.02460079, 0.0433701 ],
#        [1.        , 0.07134228, 0.07125089],
#        [1.        , 0.03321106, 0.06608778],
#        [1.        , 0.03813122, 0.06505516],
#        [1.        , 0.02337075, 0.04956583],
#        [1.        , 0.12300393, 0.07434875],
#        [1.        , 0.00246008, 0.04646797],
#        [1.        , 0.10578338, 0.09809905],
#        [1.        , 0.01845059, 0.06608778],
#        [1.        , 0.12054385, 0.09809905],
#        [1.        , 0.06519208, 0.0671204 ],
#        [1.        , 0.09225295, 0.08260972],
#        [1.        , 0.12177389, 0.09396856],
#        [1.        , 0.11931381, 0.05163108],
#        [1.        , 0.0344411 , 0.07021826],
#        [1.        , 0.04428141, 0.05989205],
#        [1.        , 0.04797153, 0.07641399],
#        [1.        , 0.05412173, 0.07847924],
#        [1.        , 0.03075098, 0.05059846],
#        [1.        , 0.08856283, 0.08364234],
#        [1.        , 0.06396204, 0.06195729],
#        [1.        , 0.02952094, 0.06402254],
#        [1.        , 0.1094735 , 0.09706642],
#        [1.        , 0.02952094, 0.06505516],
#        [1.        , 0.08364267, 0.07125089],
#        [1.        , 0.07995255, 0.07951186],
#        [1.        , 0.08610275, 0.08880545],
#        [1.        , 0.11562369, 0.09706642],
#        [1.        , 0.09594306, 0.07434875],
#        [1.        , 0.00246008, 0.05472894],
#        [1.        , 0.12300393, 0.10016429],
#        [1.        , 0.06765216, 0.0671204 ],
#        [1.        , 0.09471302, 0.07331613],
#        [1.        , 0.09963318, 0.06815302],
#        [1.        , 0.12054385, 0.09396856],
#        [1.        , 0.09840314, 0.08674021],
#        [1.        , 0.03321106, 0.05679418],
#        [1.        , 0.0344411 , 0.06402254],
#        [1.        , 0.11562369, 0.0815771 ],
#        [1.        , 0.03075098, 0.05885943],
#        [1.        , 0.09102291, 0.07228351],
#        [1.        , 0.02583082, 0.04853321],
#        [1.        , 0.06519208, 0.06402254],
#        [1.        , 0.07749247, 0.0815771 ],
#        [1.        , 0.08364267, 0.05989205],
#        [1.        , 0.07011224, 0.08260972],
#        [1.        , 0.02706086, 0.06298991],
#        [1.        , 0.05904189, 0.06402254],
#        [1.        , 0.04551145, 0.06608778],
#        [1.        , 0.05043161, 0.08777283],
#        [1.        , 0.0282909 , 0.0526637 ],
#        [1.        , 0.04305137, 0.05989205],
#        [1.        , 0.01107035, 0.04440273],
#        [1.        , 0.01107035, 0.05576156],
#        [1.        , 0.05535177, 0.07641399],
#        [1.        , 0.07995255, 0.05679418],
#        [1.        , 0.05043161, 0.04233748],
#        [1.        , 0.08733279, 0.07538137],
#        [1.        , 0.01353043, 0.06815302],
#        [1.        , 0.11193357, 0.08364234],
#        [1.        , 0.09840314, 0.07125089],
#        [1.        , 0.08979287, 0.07434875],
#        [1.        , 0.0405913 , 0.05163108],
#        [1.        , 0.04797153, 0.05989205],
#        [1.        , 0.03198102, 0.05059846],
#        [1.        , 0.01968063, 0.08054448],
#        [1.        , 0.00861027, 0.05782681],
#        [1.        , 0.02583082, 0.03717438],
#        [1.        , 0.09225295, 0.09293594],
#        [1.        , 0.05904189, 0.06092467],
#        [1.        , 0.1094735 , 0.09809905],
#        [1.        , 0.07626244, 0.07434875],
#        [1.        , 0.07749247, 0.06505516],
#        [1.        , 0.11193357, 0.10326215],
#        [1.        , 0.08979287, 0.06298991],
#        [1.        , 0.0688822 , 0.07641399],
#        [1.        , 0.0061502 , 0.06815302],
#        [1.        , 0.01353043, 0.06092467],
#        [1.        , 0.062732  , 0.06298991],
#        [1.        , 0.07626244, 0.07228351],
#        [1.        , 0.08118259, 0.05782681],
#        [1.        , 0.07749247, 0.07847924],
#        [1.        , 0.07995255, 0.08054448],
#        [1.        , 0.062732  , 0.06092467],
#        [1.        , 0.11685373, 0.07641399],
#        [1.        , 0.05535177, 0.06608778],
#        [1.        , 0.02460079, 0.05576156],
#        [1.        , 0.01230039, 0.05369632],
#        [1.        , 0.04920157, 0.07125089],
#        [1.        , 0.07995255, 0.07847924],
#        [1.        , 0.03690118, 0.06195729],
#        [1.        , 0.05535177, 0.06505516],
#        [1.        , 0.09594306, 0.07228351],
#        [1.        , 0.04797153, 0.06195729],
#        [1.        , 0.00984031, 0.0526637 ],
#        [1.        , 0.05166165, 0.08054448],
#        [1.        , 0.01353043, 0.05576156],
#        [1.        , 0.07626244, 0.06195729],
#        [1.        , 0.03567114, 0.06092467],
#        [1.        , 0.02583082, 0.05369632],
#        [1.        , 0.10086322, 0.08983807],
#        [1.        , 0.05904189, 0.07538137],
#        [1.        , 0.02706086, 0.0433701 ],
#        [1.        , 0.11193357, 0.10119691],
#        [1.        , 0.07995255, 0.08674021],
#        [1.        , 0.08487271, 0.07538137],
#        [1.        , 0.062732  , 0.07434875],
#        [1.        , 0.11193357, 0.07125089],
#        [1.        , 0.12054385, 0.0815771 ]])

# %%
y_data = data[:, -1] # paid 여부 표시
y_data = y_data.reshape(y_data.shape[0], 1)

x_data.shape, y_data.shape
# Out:
# ((200, 3), (200, 1))

# %%
x_data

# %%
y_data

# %%
x_data[:3]

# %%
y_data[:3]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(z)) # sigmoid 직접 구현
    # z에 아직 마이너스를 아직 안해줬다 !

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def hypothesis_function(x, theta):
    z = (np.dot(-x,theta)) # 여기서 마이너스를 넣었다
    return sigmoid(z)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def compute_cost(x, y, theta):
    m = y.shape[0]
    J = (-1.0 / m )* (
        y.T.dot(np.log(hypothesis_function(x,theta))) + \
        (1-y).T.dot(np.log(1- hypothesis_function(x,theta))))
    
    return (-1.0 /m )* (y * np.log(hypothesis_function(x,theta)) + (1-y) \
            * np.log(1- hypothesis_function(x,theta))).sum()
    ## J와 return과 동일한 코드이다 !

# %%
from copy import copy
def minimize_gradient(x, y, theta, iterations=100000, alpha=0.01):
    m = y.size
    cost_history = []
    theta_history = []
    
    
    for _ in range(iterations):
        original_theta = copy(theta)
        
        for i in range(theta.size):
            partial_marginal = x[:, i].reshape(x.shape[0], 1)
            delta = hypothesis_function(x, original_theta) - y
            grad_i = delta.T.dot(partial_marginal)
            
            theta[i] = theta[i] - (alpha  * grad_i)
        
        if (_ % 100) == 0:
            theta_history.append(theta)
            cost_history.append(compute_cost(x, y, theta))

    return theta, np.array(cost_history), np.array(theta_history)

# %% [markdown]
# gradient descent가 해당 수식이므로
#
# ![image.png](attachment:image.png)

# %% [markdown]
# partial_marginal
#
# ![image.png](attachment:image.png)

# %% [markdown]
# delta
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 해당 두 수식을 dot

# %%
theta_initial = np.ones([3,1])
theta, cost_history, theta_history = minimize_gradient(
    x_data, y_data,theta_initial, 10000, 0.001)

# %%
theta_initial

# %%
theta

# %%
sigmoid(-x_data.dot(theta)) >= 0.5

# %%
sum((sigmoid(-x_data.dot(theta)) > 0.3) == y_data) / len(y_data)

# %%
sum((sigmoid(-x_data.dot(theta)) > 0.3) == y_data) / len(y_data)
